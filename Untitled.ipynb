# %%
import numpy as np
import librosa

import matplotlib.pyplot as plt
from matplotlib import animation
import seaborn as sns

from IPython.display import Audio

# %%
y, sr = librosa.load('Fanfare60.wav')

# %%
print(len(y), sr)
# Out:
# 1323000 22050

# %%
print(len(y)/sr)
print(1/sr)
# Out:
# 60.0
# 4.5351473922902495e-05

# %%
Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = np.linspace(0, 27, len(y))

# %%
print(x)
# Out:
# [0.00000000e+00 2.04081787e-05 4.08163574e-05 ... 2.69999592e+01
#  2.69999796e+01 2.70000000e+01]

# %%
len(x)
# Out:
# 1323000

# %%
plt.plot(x, y)

# %%
STFT = np.abs(librosa.core.stft(y))

# %%
STFT
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.5686578 , 0.14310083,
#         0.4810976 ],
#        [0.        , 0.        , 0.        , ..., 0.321865  , 0.26897874,
#         0.4669628 ],
#        [0.        , 0.        , 0.        , ..., 0.12468008, 0.04260095,
#         0.22573118],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.00684823, 0.0080365 ,
#         0.00761699],
#        [0.        , 0.        , 0.        , ..., 0.00286191, 0.0033735 ,
#         0.0068766 ],
#        [0.        , 0.        , 0.        , ..., 0.00336199, 0.00349893,
#         0.00258242]], dtype=float32)

# %%
STFT.shape
# Out:
# (1025, 2584)

# %%
STFT[0]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.5686578 , 0.14310083,
#        0.4810976 ], dtype=float32)

# %%
STFT[1]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.321865  , 0.26897874,
#        0.4669628 ], dtype=float32)

# %%
librosa.core.fft_frequencies(sr, n_fft=8)
# Out:
# array([    0.  ,  2756.25,  5512.5 ,  8268.75, 11025.  ])

# %%
librosa.frames_to_samples(STFT)
# Out:
# array([[  0,   0,   0, ..., 291,  73, 246],
#        [  0,   0,   0, ..., 164, 137, 239],
#        [  0,   0,   0, ...,  63,  21, 115],
#        ...,
#        [  0,   0,   0, ...,   3,   4,   3],
#        [  0,   0,   0, ...,   1,   1,   3],
#        [  0,   0,   0, ...,   1,   1,   1]])

# %%
STFT.shape
# Out:
# (1025, 2584)
